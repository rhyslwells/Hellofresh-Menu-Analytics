-- %%
-- SELECT
--   customer_id,
--   COUNT(customer_id) AS total_orders
-- FROM
--   sales_orders
-- GROUP BY
--   customer_id
-- ORDER BY
--   total_orders DESC

SELECT
  so.customer_id,
  so.customer_name,
  COUNT(so.customer_id) AS total_orders
FROM
  sales_orders AS so
GROUP BY
  so.customer_id,
  so.customer_name
ORDER BY
  total_orders DESC
